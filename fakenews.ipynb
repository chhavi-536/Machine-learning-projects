# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\dell\\OneDrive\\Desktop\\train.csv")
df
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# ...

# %%
df.drop(columns = ['id'],inplace =True)

# %%
df.isnull().sum()
# Out:
# title      558
# author    1957
# text        39
# label        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 109

# %%
df = df.drop_duplicates(keep ='first')

# %% [markdown]
# #EDA

# %%
df['label'].value_counts()
# Out:
# label
# 0    10387
# 1    10304
# Name: count, dtype: int64

# %%
X = df.drop(columns=['label', 'text'])

# %%
X
# Out:
#                                                    title  \
# 0      House Dem Aide: We Didn’t Even See Comey’s Let...
# 1      FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2                      Why the Truth Might Get You Fired
# 3      15 Civilians Killed In Single US Airstrike Hav...
# 4      Iranian woman jailed for fictional unpublished...
# ...                                                  ...
# 20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799                          What Keeps the F-35 Alive
#
#                                           author
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# 2                             Consortiumnews.com
# 3                                Jessica Purkiss
# ...

# %%
X['content'] = df['author']+' '+ df['title']

# %%
y = df.iloc[ : ,3:]

# %%
X.drop(columns = ['title','author'])
# Out:
#                                                  content
# 0      Darrell Lucus House Dem Aide: We Didn’t Even S...
# 1      Daniel J. Flynn FLYNN: Hillary Clinton, Big Wo...
# 2      Consortiumnews.com Why the Truth Might Get You...
# 3      Jessica Purkiss 15 Civilians Killed In Single ...
# 4      Howard Portnoy Iranian woman jailed for fictio...
# ...                                                  ...
# 20795  Jerome Hudson Rapper T.I.: Trump a ’Poster Chi...
# 20796  Benjamin Hoffman N.F.L. Playoffs: Schedule, Ma...
# 20797  Michael J. de la Merced and Rachel Abrams Macy...
# 20798  Alex Ansary NATO, Russia To Hold Parallel Exer...
# 20799            David Swanson What Keeps the F-35 Alive
#
# [20691 rows x 1 columns]

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
X['content_length'] = X['content'].apply(lambda x: len(x) if isinstance(x, str) else None)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20691 entries, 0 to 20799
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           20173 non-null  object
#  1   author          18759 non-null  object
#  2   content         18241 non-null  object
#  3   content_length  18241 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 808.2+ KB

# %%
from nltk.tokenize import word_tokenize

X['word_count'] = X['content'].apply(lambda x: len(word_tokenize(x)) if isinstance(x, str) else 0)

# %%
from nltk.tokenize import sent_tokenize
X['sent_count'] = X['content'].apply(lambda x: len(sent_tokenize(x)) if isinstance(x, str) else 0)

# %%
X.drop(columns = ['title','author'],inplace = True)

# %%
X
# Out:
#                                                  content  content_length  \
# 0      Darrell Lucus House Dem Aide: We Didn’t Even S...            95.0
# 1      Daniel J. Flynn FLYNN: Hillary Clinton, Big Wo...            71.0
# 2      Consortiumnews.com Why the Truth Might Get You...            52.0
# 3      Jessica Purkiss 15 Civilians Killed In Single ...            79.0
# 4      Howard Portnoy Iranian woman jailed for fictio...           108.0
# ...                                                  ...             ...
# 20795  Jerome Hudson Rapper T.I.: Trump a ’Poster Chi...            69.0
# 20796  Benjamin Hoffman N.F.L. Playoffs: Schedule, Ma...            82.0
# 20797  Michael J. de la Merced and Rachel Abrams Macy...           122.0
# 20798  Alex Ansary NATO, Russia To Hold Parallel Exer...            62.0
# 20799            David Swanson What Keeps the F-35 Alive            39.0
#
#        word_count  sent_count
# 0              21           1
# ...

# %%
X.describe()
# Out:
#        content_length    word_count    sent_count
# count    18241.000000  20691.000000  20691.000000
# mean        91.239625     14.830506      0.978783
# std         26.547361      7.469430      0.503429
# min         12.000000      0.000000      0.000000
# 25%         75.000000     11.000000      1.000000
# 50%         92.000000     16.000000      1.000000
# 75%        106.000000     20.000000      1.000000
# max        489.000000     85.000000      7.000000

# %%
X.shape
# Out:
# (20691, 4)

# %%
X.isnull().sum()
# Out:
# content           2450
# content_length    2450
# word_count           0
# sent_count           0
# dtype: int64

# %%
X['labels'] = df['label']
X
# Out:
#                                                  content  content_length  \
# 0      Darrell Lucus House Dem Aide: We Didn’t Even S...            95.0
# 1      Daniel J. Flynn FLYNN: Hillary Clinton, Big Wo...            71.0
# 2      Consortiumnews.com Why the Truth Might Get You...            52.0
# 3      Jessica Purkiss 15 Civilians Killed In Single ...            79.0
# 4      Howard Portnoy Iranian woman jailed for fictio...           108.0
# ...                                                  ...             ...
# 20795  Jerome Hudson Rapper T.I.: Trump a ’Poster Chi...            69.0
# 20796  Benjamin Hoffman N.F.L. Playoffs: Schedule, Ma...            82.0
# 20797  Michael J. de la Merced and Rachel Abrams Macy...           122.0
# 20798  Alex Ansary NATO, Russia To Hold Parallel Exer...            62.0
# 20799            David Swanson What Keeps the F-35 Alive            39.0
#
#        word_count  sent_count  labels
# 0              21           1       1
# ...

# %%
X[X['labels'] == 0][['content_length','word_count','sent_count']].describe()
# Out:
#        content_length    word_count    sent_count
# count    10361.000000  10387.000000  10387.000000
# mean        97.360486     18.265043      1.113989
# std         18.729765      4.197481      0.399431
# min         36.000000      0.000000      0.000000
# 25%         85.000000     16.000000      1.000000
# 50%         97.000000     18.000000      1.000000
# 75%        109.000000     21.000000      1.000000
# max        197.000000     37.000000      5.000000

# %%
X[X['labels'] == 1][['content_length','word_count','sent_count']].describe()
# Out:
#        content_length    word_count    sent_count
# count     7880.000000  10304.000000  10304.000000
# mean        83.191624     11.368304      0.842488
# std         32.499564      8.390390      0.557772
# min         12.000000      0.000000      0.000000
# 25%         63.000000      5.000000      1.000000
# 50%         81.000000     12.000000      1.000000
# 75%         99.000000     17.000000      1.000000
# max        489.000000     85.000000      7.000000
